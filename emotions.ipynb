# %%
# %pip install tensorflow==2.15.0
# %pip install scikit-learn
# %pip install pandas
# %pip install numpy
# %pip install seaborn
# %pip install matplotlib
# %pip install wordcloud
# %pip install nltk
# Out:
# Requirement already satisfied: tensorflow==2.15.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.62.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from scikit-learn) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: wordcloud in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from wordcloud) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib->wordcloud) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nltk in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in c:\users\10app\desktop\human-emotion-detection-\human-emotion-detection-\env\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Libraries

# %%
# dl packages
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
# ml packages
from sklearn.preprocessing import LabelEncoder
import numpy as np
import pandas as pd
import pickle
import nltk
import re
from nltk.stem import PorterStemmer

import seaborn as sns
import matplotlib.pyplot as plt

from wordcloud import WordCloud
# Out:
# WARNING:tensorflow:From c:\Users\10app\Desktop\Human-Emotion-Detection-\Human-Emotion-Detection-\env\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Loading Data

# %%
train_data = pd.read_csv("train.txt", header=None, sep=";", names=["Comment", "Emotion"], encoding="utf-8")
# get all words length in comment
train_data['length'] = [len(x) for x in train_data['Comment']]

# %%
train_data
# Out:
#                                                  Comment  Emotion  length
# 0                                i didnt feel humiliated  sadness      23
# 1      i can go from feeling so hopeless to so damned...  sadness     108
# 2       im grabbing a minute to post i feel greedy wrong    anger      48
# 3      i am ever feeling nostalgic about the fireplac...     love      92
# 4                                   i am feeling grouchy    anger      20
# ...                                                  ...      ...     ...
# 15995  i just had a very brief time in the beanbag an...  sadness     101
# 15996  i am now turning and i feel pathetic that i am...  sadness     102
# 15997                     i feel strong and good overall      joy      30
# 15998  i feel like this was such a rude comment and i...    anger      59
# 15999  i know a lot but i feel so stupid because i ca...  sadness      62
#
# [16000 rows x 3 columns]

# %%
# number of rows and columns
train_data.shape
# Out:
# (16000, 3)

# %%
# to count the number of missing values 
train_data.isnull().sum()
# Out:
# Comment    0
# Emotion    0
# length     0
# dtype: int64

# %%
# used to count the number of duplicate rows
train_data.duplicated().sum()
# Out:
# 1

# %%
train_data.drop_duplicates(inplace=True)

# %%
train_data['Emotion'].value_counts()
# Out:
# Emotion
# joy         5361
# sadness     4666
# anger       2159
# fear        1937
# love        1304
# surprise     572
# Name: count, dtype: int64

# %%
# to create a count plot based on the "Emotion" column 
sns.countplot(x = train_data['Emotion'])
plt.show()

# %%
# data distribution
df2 = train_data.copy()
df2['length'] = [len(x) for x in df2['Comment']]

# Convert the 'length' column to a numpy array
length_values = df2['length'].values

# sns.histplot to create histogram stacked on top of each other
sns.histplot(data=df2, x='length', hue='Emotion', multiple='stack')

plt.show()

# %%
# Words cloud for each emotions
def words_cloud(wordcloud, df):
    plt.figure(figsize=(10, 10))
    plt.title(df+' Word Cloud', size = 16)
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");
emotions_list = train_data['Emotion'].unique()
for emotion in emotions_list:
    text = ' '.join([sentence for sentence in train_data.loc[train_data['Emotion'] == emotion,'Comment']])
    wordcloud = WordCloud(width = 600, height = 600).generate(text)
    words_cloud(wordcloud, emotion)

# %% [markdown]
# # Data Processing
# # Encode Emotions

# %%
lb = LabelEncoder()
train_data['Emotion Encoded'] = lb.fit_transform(train_data['Emotion'])

# %%
train_data
# Out:
#                                                  Comment  Emotion  length  \
# 0                                i didnt feel humiliated  sadness      23
# 1      i can go from feeling so hopeless to so damned...  sadness     108
# 2       im grabbing a minute to post i feel greedy wrong    anger      48
# 3      i am ever feeling nostalgic about the fireplac...     love      92
# 4                                   i am feeling grouchy    anger      20
# ...                                                  ...      ...     ...
# 15995  i just had a very brief time in the beanbag an...  sadness     101
# 15996  i am now turning and i feel pathetic that i am...  sadness     102
# 15997                     i feel strong and good overall      joy      30
# 15998  i feel like this was such a rude comment and i...    anger      59
# 15999  i know a lot but i feel so stupid because i ca...  sadness      62
#
#        Emotion Encoded
# 0                    4
# 1                    4
# 2                    0
# 3                    3
# 4                    0
# ...                ...
# 15995                4
# 15996                4
# 15997                2
# 15998                0
# 15999                4
#
# [15999 rows x 4 columns]

# %% [markdown]
# # Applying Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
df = train_data.copy()

# %%
df
# Out:
#                                                  Comment  Emotion  length  \
# 0                                i didnt feel humiliated  sadness      23
# 1      i can go from feeling so hopeless to so damned...  sadness     108
# 2       im grabbing a minute to post i feel greedy wrong    anger      48
# 3      i am ever feeling nostalgic about the fireplac...     love      92
# 4                                   i am feeling grouchy    anger      20
# ...                                                  ...      ...     ...
# 15995  i just had a very brief time in the beanbag an...  sadness     101
# 15996  i am now turning and i feel pathetic that i am...  sadness     102
# 15997                     i feel strong and good overall      joy      30
# 15998  i feel like this was such a rude comment and i...    anger      59
# 15999  i know a lot but i feel so stupid because i ca...  sadness      62
#
#        Emotion Encoded
# 0                    4
# 1                    4
# 2                    0
# 3                    3
# 4                    0
# ...                ...
# 15995                4
# 15996                4
# 15997                2
# 15998                0
# 15999                4
#
# [15999 rows x 4 columns]

# %%
# Data cleaning and preprocessing
# Download NLTK stopwords
nltk.download('stopwords') # contains stop words in english like i, am ,and, the, etc
stopwords = set(nltk.corpus.stopwords.words('english'))
def clean_text(text):
    stemmer = PorterStemmer() # loved, loving, loves; among these type verb form it'll take 'love'
    text = re.sub("[^a-zA-Z]", " ", text)  # Remove non-alphabetic characters
    text = text.lower()  # Convert text to lowercase
    text = text.split()  # Split text into words
    text = [stemmer.stem(word) for word in text if word not in stopwords]  # Stem words and remove stopwords
    return " ".join(text)  # Join cleaned words back into a single string


df['cleaned_comment'] = df['Comment'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\10app\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df
# Out:
#                                                  Comment  Emotion  length  \
# 0                                i didnt feel humiliated  sadness      23
# 1      i can go from feeling so hopeless to so damned...  sadness     108
# 2       im grabbing a minute to post i feel greedy wrong    anger      48
# 3      i am ever feeling nostalgic about the fireplac...     love      92
# 4                                   i am feeling grouchy    anger      20
# ...                                                  ...      ...     ...
# 15995  i just had a very brief time in the beanbag an...  sadness     101
# 15996  i am now turning and i feel pathetic that i am...  sadness     102
# 15997                     i feel strong and good overall      joy      30
# 15998  i feel like this was such a rude comment and i...    anger      59
# 15999  i know a lot but i feel so stupid because i ca...  sadness      62
#
#        Emotion Encoded                                    cleaned_comment
# 0                    4                                  didnt feel humili
# 1                    4  go feel hopeless damn hope around someon care ...
# 2                    0               im grab minut post feel greedi wrong
# 3                    3     ever feel nostalg fireplac know still properti
# 4                    0                                       feel grouchi
# ...                ...                                                ...
# 15995                4      brief time beanbag said anna feel like beaten
# 15996                4   turn feel pathet still wait tabl sub teach degre
# 15997                2                            feel strong good overal
# 15998                0                     feel like rude comment im glad
# 15999                4                       know lot feel stupid portray
#
# [15999 rows x 5 columns]

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(df['cleaned_comment'],df['Emotion Encoded'],test_size=0.2,random_state=42)

# %%
# Vectorization using TF-IDF  (Term Frequency-Inverse Document Frequency) 
tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
# Multi-class classification using different algorithms
classifiers = {
    "Multinomial Naive Bayes": MultinomialNB(),
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Support Vector Machine": SVC(),
}

for name, clf in classifiers.items():
    print(f"\n===== {name} =====")
    clf.fit(X_train_tfidf, y_train)
    y_pred_tfidf = clf.predict(X_test_tfidf)
    accuracy_tfidf = accuracy_score(y_test, y_pred_tfidf)
    print(f"\nAccuracy using TF-IDF: {accuracy_tfidf}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred_tfidf))
# Out:
# ===== Multinomial Naive Bayes =====
#
# Accuracy using TF-IDF: 0.6590625
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.32      0.48       439
#            1       0.88      0.23      0.37       375
#            2       0.58      0.98      0.73      1027
#            3       1.00      0.03      0.05       303
#            4       0.72      0.91      0.80       950
#            5       1.00      0.02      0.04       106
#
#     accuracy                           0.66      3200
#    macro avg       0.85      0.42      0.41      3200
# weighted avg       0.76      0.66      0.59      3200
#
#
# ===== Logistic Regression =====
#
# Accuracy using TF-IDF: 0.825
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83       439
#            1       0.85      0.72      0.78       375
#            2       0.76      0.94      0.84      1027
#            3       0.84      0.47      0.60       303
#            4       0.88      0.92      0.90       950
#            5       0.74      0.45      0.56       106
#
#     accuracy                           0.82      3200
#    macro avg       0.82      0.71      0.75      3200
# weighted avg       0.83      0.82      0.82      3200
#
#
# ===== Random Forest =====
#
# Accuracy using TF-IDF: 0.84625
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       439
#            1       0.82      0.85      0.83       375
#            2       0.84      0.89      0.86      1027
#            3       0.82      0.61      0.70       303
#            4       0.91      0.88      0.90       950
#            5       0.70      0.72      0.71       106
#
#     accuracy                           0.85      3200
#    macro avg       0.82      0.80      0.81      3200
# weighted avg       0.85      0.85      0.84      3200
#
#
# ===== Support Vector Machine =====
#
# Accuracy using TF-IDF: 0.815625
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       439
#            1       0.84      0.73      0.78       375
#            2       0.75      0.94      0.83      1027
#            3       0.82      0.37      0.51       303
#            4       0.87      0.90      0.89       950
#            5       0.82      0.47      0.60       106
#
#     accuracy                           0.82      3200
#    macro avg       0.83      0.70      0.74      3200
# weighted avg       0.82      0.82      0.80      3200

# %%
# selecting model
lg = LogisticRegression()
lg.fit(X_train_tfidf, y_train)
lg_y_pred = lg.predict(X_test_tfidf)

# %%
def predict_emotion(input_text):
    cleaned_text = clean_text(input_text)
    input_vectorized = tfidf_vectorizer.transform([cleaned_text])

    # Predict emotion
    predicted_label = lg.predict(input_vectorized)[0]
    predicted_emotion = lb.inverse_transform([predicted_label])[0]
    label =  np.max(lg.predict(input_vectorized))

    return predicted_emotion,label

# Example usage 
sentences = [
            "i didnt feel humiliated",
            "i feel strong and good overall",
            "im grabbing a minute to post i feel greedy wrong",
            "He was speechles when he found out he was accepted to this new job",
            "This is outrageous, how can you talk like that?",
            "I feel like im all alone in this world",
            "He is really sweet and caring",
            "You made me very crazy",
            "i am ever feeling nostalgic about the fireplace i will know that it is still on the property",
            "i am feeling grouchy",
            "He hates you"
            ]
for sentence in sentences:
    print(sentence)
    pred_emotion, label = predict_emotion(sentence)
    print("Prediction :",pred_emotion)
    print("Label :",label)
    print("================================================================")
# Out:
# i didnt feel humiliated
# Prediction : sadness
# Label : 4
# ================================================================
# i feel strong and good overall
# Prediction : joy
# Label : 2
# ================================================================
# im grabbing a minute to post i feel greedy wrong
# Prediction : anger
# Label : 0
# ================================================================
# He was speechles when he found out he was accepted to this new job
# Prediction : joy
# Label : 2
# ================================================================
# This is outrageous, how can you talk like that?
# Prediction : anger
# Label : 0
# ================================================================
# I feel like im all alone in this world
# Prediction : sadness
# Label : 4
# ================================================================
# He is really sweet and caring
# Prediction : love
# Label : 3
# ================================================================
# You made me very crazy
# Prediction : sadness
# Label : 4
# ================================================================
# i am ever feeling nostalgic about the fireplace i will know that it is still on the property
# Prediction : love
# Label : 3
# ================================================================
# i am feeling grouchy
# Prediction : anger
# Label : 0
# ================================================================
# He hates you
# Prediction : anger
# Label : 0
# ================================================================

# %%
# save files
import pickle
pickle.dump(lg,open("logistic_regresion.pkl",'wb'))
pickle.dump(lb,open("label_encoder.pkl",'wb'))
pickle.dump(tfidf_vectorizer,open("tfidf_vectorizer.pkl",'wb'))

# %%
import sklearn
print(sklearn.__version__) # using this version in pycharm
# Out:
# 1.4.1.post1

# %% [markdown]
# # Applying Deep Learning using LSTM
# # Text Cleaning, encoding and padding

# %%
train_data
# Out:
#                                                  Comment  Emotion  length  \
# 0                                i didnt feel humiliated  sadness      23
# 1      i can go from feeling so hopeless to so damned...  sadness     108
# 2       im grabbing a minute to post i feel greedy wrong    anger      48
# 3      i am ever feeling nostalgic about the fireplac...     love      92
# 4                                   i am feeling grouchy    anger      20
# ...                                                  ...      ...     ...
# 15995  i just had a very brief time in the beanbag an...  sadness     101
# 15996  i am now turning and i feel pathetic that i am...  sadness     102
# 15997                     i feel strong and good overall      joy      30
# 15998  i feel like this was such a rude comment and i...    anger      59
# 15999  i know a lot but i feel so stupid because i ca...  sadness      62
#
#        Emotion Encoded
# 0                    4
# 1                    4
# 2                    0
# 3                    3
# 4                    0
# ...                ...
# 15995                4
# 15996                4
# 15997                2
# 15998                0
# 15999                4
#
# [15999 rows x 4 columns]
